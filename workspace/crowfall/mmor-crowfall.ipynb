# %%
# !git clone "https://Pyetrek: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@github.com/Pyetrek/mmor-crowfall-models.git"
# Out:
# Cloning into 'mmor-crowfall-models'...
# remote: Enumerating objects: 2832, done.
# remote: Counting objects: 100% (2832/2832), done.
# remote: Compressing objects: 100% (2114/2114), done.
# remote: Total 2832 (delta 683), reused 2828 (delta 680), pack-reused 0
# Receiving objects: 100% (2832/2832), 34.60 MiB | 23.96 MiB/s, done.
# Resolving deltas: 100% (683/683), done.

# %% [markdown]
# Had some conflicting versions. Ran `!pip install "requests~=2.23.0"` to try and solve the object detection pip install. That didn't work, so I did `!pip install "requests~=2.26.0"` to go back to the new version and things just worked?

# %%
# %cd /content/mmor-crowfall-models/models/research/
# !protoc object_detection/protos/*.proto --python_out=.
# !pip install "requests~=2.26.0"
# !cp object_detection/packages/tf2/setup.py .
# !python -m pip install --use-feature=2020-resolver .

# %%
# %cd /content/mmor-crowfall-models/models/research/
# !python object_detection/builders/model_builder_tf2_test.py

# %%
# !pip install --ignore-installed --upgrade tensorflow==2.5.0
# Out:
# ...
#      |████████████████████████████████| 454.3 MB 16 kB/s
# ...
#      |████████████████████████████████| 1.0 MB 39.2 MB/s
# ...
#      |████████████████████████████████| 6.0 MB 47.7 MB/s
# ...
#      |████████████████████████████████| 14.8 MB 166 kB/s
# ...
#      |████████████████████████████████| 57 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 53.4 MB/s
# ...
#      |████████████████████████████████| 65 kB 3.6 MB/s
# ...
#      |████████████████████████████████| 132 kB 50.9 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.2 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 47.2 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 55.2 MB/s
# ...
#      |████████████████████████████████| 462 kB 54.7 MB/s
# ...
#      |████████████████████████████████| 4.9 MB 54.8 MB/s
# ...
#      |████████████████████████████████| 288 kB 54.8 MB/s
# ...
#      |████████████████████████████████| 781 kB 66.1 MB/s
# ...
#      |████████████████████████████████| 819 kB 56.2 MB/s
# ...
#   Using cached requests-2.26.0-py2.py3-none-any.whl (62 kB)
# ...

# %% [markdown]
# See https://www.researchgate.net/post/Could_not_load_dynamic_library_libcusolverso10_dlerror_libcusolverso10_cannot_open_shared_object_file for info about the below `ln`, gets gpu working with tensorflow

# %%
# !ln -s /usr/local/cuda/lib64/libcusolver.so.10 /usr/lib64-nvidia/libcusolver.so.11
# Out:
# ln: failed to create symbolic link '/usr/lib64-nvidia/libcusolver.so.11': No such file or directory

# %%
# !python -c "import tensorflow as tf;print(tf.reduce_sum(tf.random.normal([1000, 1000])))"
# Out:
# 2021-08-02 16:27:51.244265: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-08-02 16:27:53.173816: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-08-02 16:27:53.190310: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-08-02 16:27:53.190367: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (f4d570f41b9a): /proc/driver/nvidia/version does not exist
# 2021-08-02 16:27:53.190849: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# ...

# %% [markdown]
# Need to update cuda..... Use deb packages from https://s3.console.aws.amazon.com/s3/upload/tmb-dice-roller?region=us-east-1&prefix=mmor/

# %%
# %cd /content
# !wget "https://tmb-dice-roller.s3.us-east-1.amazonaws.com/mmor/libcudnn8-dev_8.1.0.77-1%2Bcuda11.2_amd64.deb?response-content-disposition=attachment&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEOT%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIHYy6HsCDhIutFuvdgVYT9Y7THk9BOiMo%2FzrWxpXIXyEAiEA1Zvg97aVjRwxYww9Ju4LeneegOpwLKT%2FDEBRP%2FHbcpoqsAII7f%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F
3D%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20210802T162937Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAUB3IWOHWTLCJD3M3%2F20210802%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=429e58f26c29d7dc665ccb7f46b42361cb276e3d6987fa02c0da3b1b093b2e4b"  --output-document=libcudnn8_8.1.0.77-1+cuda11.2_amd64.deb
# !dpkg -i libcudnn8_8.1.0.77-1+cuda11.2_amd64.deb
# !dpkg -i libcudnn8-dev_8.1.0.77-1+cuda11.2_amd64.deb
# !rm libcudnn8_8.1.0.77-1+cuda11.2_amd64.deb libcudnn8-dev_8.1.0.77-1+cuda11.2_amd64.deb
# !ls
# Out:
# /content
# ...

# %% [markdown]
# Let's prepare our training set and get it in the right format for tensorflow

# %%
# !pip install pandas

# %%
# %cd /content/mmor-crowfall-models/scripts/preprocessing
# Create train data:
# !python generate_tfrecord.py -x /content/mmor-crowfall-models/workspace/crowfall/images/training -l /content/mmor-crowfall-models/workspace/crowfall/annotations/label_map.pbtxt -o /content/mmor-crowfall-models/workspace/crowfall/annotations/train.record

# Create test data:
# !python generate_tfrecord.py -x /content/mmor-crowfall-models/workspace/crowfall/images/test -l /content/mmor-crowfall-models/workspace/crowfall/annotations/label_map.pbtxt -o /content/mmor-crowfall-models/workspace/crowfall/annotations/test.record
# Out:
# /content/mmor-crowfall-models/scripts/preprocessing
# Successfully created the TFRecord file: /content/mmor-crowfall-models/workspace/crowfall/annotations/train.record
# Successfully created the TFRecord file: /content/mmor-crowfall-models/workspace/crowfall/annotations/test.record

# %%
# %cd /content/mmor-crowfall-models/workspace/crowfall/
# !mkdir pre-trained-models 
# %cd /content/mmor-crowfall-models/workspace/crowfall/pre-trained-models
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz
# !tar xvzf ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz
# !rm ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz
# Out:
# /content/mmor-crowfall-models/workspace/crowfall
# /content/mmor-crowfall-models/workspace/crowfall/pre-trained-models
# --2021-08-02 16:38:51--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 108.177.119.128, 2a00:1450:4013:c00::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|108.177.119.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 244817203 (233M) [application/x-tar]
# Saving to: ‘ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz’
#
# ssd_resnet50_v1_fpn 100%[===================>] 233.48M  70.5MB/s    in 3.3s
#
# 2021-08-02 16:38:55 (70.5 MB/s) - ‘ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz’ saved [244817203/244817203]
#
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/
# ...

# %% [markdown]
# Now to train....

# %%
# %cd /content/mmor-crowfall-models/
# !cp models/research/object_detection/model_main_tf2.py workspace/crowfall
# %cd /content/mmor-crowfall-models/workspace/crowfall
# !python model_main_tf2.py --model_dir=models/crowfall_ssd_resnet50_v1_fpn --pipeline_config_path=models/crowfall_ssd_resnet50_v1_fpn/pipeline.config
# Out:
# /content/mmor-crowfall-models
# /content/mmor-crowfall-models/workspace/crowfall
# 2021-08-02 16:39:25.266066: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-08-02 16:39:29.335037: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-08-02 16:39:29.347602: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-08-02 16:39:29.347672: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (f4d570f41b9a): /proc/driver/nvidia/version does not exist
# ...

# %%
# %cd /content/mmor-crowfall-models/workspace/crowfall
# !git pull
# !ls
#!rm ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz

# %%
# %cd /content
# !ls
# Out:
# /content
# cuda  mmor-crowfall-models  sample_data
